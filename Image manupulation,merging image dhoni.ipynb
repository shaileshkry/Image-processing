# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img1=cv.imread('0a97835a61.jpg')

# %%
img1.shape
# Out:
# (224, 224, 3)

# %%
img1[1].shape
# Out:
# (224, 3)

# %%
plt.imshow(img1)

# %%
img1=cv.imread('0a97835a61.jpg')
for i in range(len(img1)):
    k=0
    for j in range(len(img1[0])):
        img1[i][j][0]=k%250
    k+=k
plt.imshow(img1)

# %%
img2=cv.imread('0c90a193c7.jpg')

# %%
img2.shape
# Out:
# (177, 284, 3)

# %%
plt.imshow(img2)

# %%
img2[0][0]
# Out:
# array([84, 79, 78], dtype=uint8)

# %%
len(img2)
# Out:
# 177

# %%
len(img2[0])
# Out:
# 284

# %%
img2[0][0]
# Out:
# array([84, 79, 78], dtype=uint8)

# %%
(img2[0][0]+100)%250
# Out:
# array([184, 179, 178], dtype=uint8)

# %%
img2=cv.imread('0c90a193c7.jpg')
for i in range(len(img2)):
    k=0
    for j in range(len(img2[0])):
        img2[i][j][0]=k%250
    k+=k
plt.imshow(img2)

# %%
img2=cv.imread('0c90a193c7.jpg')
for i in range(len(img2)):
    for j in range(len(img2[0])):
        img2[i][j][0]=img1[i%177][j%224][0]
plt.imshow(img2)

# %%
img2=cv.resize(img2,(img1.shape[1],img1.shape[0]))

# %%
img2.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# ### Merging two images

# %%
img=0.01*img1+.003*img2

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(cv.addWeighted(img1,0.2,img2,0.9,0))
